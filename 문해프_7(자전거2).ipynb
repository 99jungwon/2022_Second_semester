# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib as mpl
from datetime import datetime

# %%
# pd.read_csv로 csv파일 불러오기
train = pd.read_csv('train_data (1).csv')
train
# Out:
#                  datetime  season  holiday  workingday  weather   temp  \
# 0     2012-06-03 10:00:00       2        0           0        1  25.42
# 1     2012-08-11 10:00:00       3        0           0        1  29.52
# 2     2011-01-05 23:00:00       1        0           1        1   8.20
# 3     2011-04-06 07:00:00       2        0           1        1  10.66
# 4     2012-10-16 05:00:00       4        0           1        1  17.22
# ...                   ...     ...      ...         ...      ...    ...
# 8703  2012-12-01 02:00:00       4        0           0        2  10.66
# 8704  2012-10-18 06:00:00       4        0           1        1  18.04
# 8705  2012-07-14 20:00:00       3        0           0        1  29.52
# 8706  2012-04-14 13:00:00       2        0           0        1  25.42
# 8707  2011-09-03 01:00:00       3        0           0        2  26.24
#
#        atemp  humidity  windspeed  casual  registered  count
# 0     31.060        43    15.0013     127         277    404
# 1     34.090        62     6.0032     125         282    407
# 2     12.880        47     0.0000       1          18     19
# 3     13.635        65     7.0015       3         130    133
# 4     21.210        67    16.9979       5          47     52
# ...      ...       ...        ...     ...         ...    ...
# 8703  15.150        81     0.0000       3          47     50
# 8704  21.970        88    19.9995       3         150    153
# 8705  35.605        84     6.0032     101         255    356
# 8706  31.060        33    19.9995     308         370    678
# 8707  30.305        69    16.9979      17          57     74
#
# [8708 rows x 12 columns]

# %%
# pd.read_csv로 csv파일 불러오기
test = pd.read_csv('test_data (1).csv')
test
# Out:
#                  datetime  season  holiday  workingday  weather   temp  \
# 0     2012-11-18 19:00:00       4        0           0        1  14.76
# 1     2011-01-13 11:00:00       1        0           1        2   8.20
# 2     2012-08-19 02:00:00       3        0           0        2  25.42
# 3     2011-09-13 05:00:00       3        0           1        1  22.96
# 4     2012-06-18 03:00:00       2        0           1        2  21.32
# ...                   ...     ...      ...         ...      ...    ...
# 2173  2012-06-14 14:00:00       2        0           1        1  28.70
# 2174  2012-12-01 22:00:00       4        0           0        2  12.30
# 2175  2012-11-19 19:00:00       4        0           1        2  16.40
# 2176  2012-12-14 01:00:00       4        0           1        1   9.02
# 2177  2012-08-15 23:00:00       3        0           1        1  27.88
#
#        atemp  humidity  windspeed  casual  registered  count
# 0     17.425        66    11.0014      16         194    210
# 1      8.335        44    30.0026       4          33     37
# 2     30.305        69     6.0032      16         103    119
# 3     26.515        88     0.0000       1          19     20
# 4     25.000        83    15.0013       1           3      4
# ...      ...       ...        ...     ...         ...    ...
# 2173  32.575        54    19.0012      84         214    298
# 2174  16.665        87     0.0000      17         130    147
# 2175  20.455        58    19.0012      25         381    406
# 2176  12.880        69     6.0032       0          26     26
# 2177  31.820        65     7.0015      18         120    138
#
# [2178 rows x 12 columns]

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
all_data = pd.concat([train, test], ignore_index = True)

# %%
all_data
# Out:
#                   datetime  season  holiday  workingday  weather   temp  \
# 0      2012-06-03 10:00:00       2        0           0        1  25.42
# 1      2012-08-11 10:00:00       3        0           0        1  29.52
# 2      2011-01-05 23:00:00       1        0           1        1   8.20
# 3      2011-04-06 07:00:00       2        0           1        1  10.66
# 4      2012-10-16 05:00:00       4        0           1        1  17.22
# ...                    ...     ...      ...         ...      ...    ...
# 10881  2012-06-14 14:00:00       2        0           1        1  28.70
# 10882  2012-12-01 22:00:00       4        0           0        2  12.30
# 10883  2012-11-19 19:00:00       4        0           1        2  16.40
# 10884  2012-12-14 01:00:00       4        0           1        1   9.02
# 10885  2012-08-15 23:00:00       3        0           1        1  27.88
#
#         atemp  humidity  windspeed  casual  registered  count
# 0      31.060        43    15.0013     127         277    404
# 1      34.090        62     6.0032     125         282    407
# 2      12.880        47     0.0000       1          18     19
# 3      13.635        65     7.0015       3         130    133
# 4      21.210        67    16.9979       5          47     52
# ...       ...       ...        ...     ...         ...    ...
# 10881  32.575        54    19.0012      84         214    298
# 10882  16.665        87     0.0000      17         130    147
# 10883  20.455        58    19.0012      25         381    406
# 10884  12.880        69     6.0032       0          26     26
# 10885  31.820        65     7.0015      18         120    138
#
# [10886 rows x 12 columns]

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
all_data['year'] = all_data['datetime'].apply(lambda x: datetime.strptime(x.split()[0], "%Y-%m-%d").year)
all_data['month'] = all_data['datetime'].apply(lambda x: datetime.strptime(x.split()[0], "%Y-%m-%d").month)
all_data['hour'] = all_data['datetime'].apply(lambda x: datetime.strptime(x.split()[1], "%H:%M:%S").hour)

# %%
all_data['year']
# Out:
# 0        2012
# 1        2012
# 2        2011
# 3        2011
# 4        2012
#          ...
# 10881    2012
# 10882    2012
# 10883    2012
# 10884    2012
# 10885    2012
# Name: year, Length: 10886, dtype: int64

# %%
all_data['month']
# Out:
# 0         6
# 1         8
# 2         1
# 3         4
# 4        10
#          ..
# 10881     6
# 10882    12
# 10883    11
# 10884    12
# 10885     8
# Name: month, Length: 10886, dtype: int64

# %%
all_data['hour']
# Out:
# 0        10
# 1        10
# 2        23
# 3         7
# 4         5
#          ..
# 10881    14
# 10882    22
# 10883    19
# 10884     1
# 10885    23
# Name: hour, Length: 10886, dtype: int64

# %%
all_data['weekday'] = all_data['datetime'].apply(lambda x: datetime.strptime(x.split()[0], "%Y-%m-%d").weekday())

# %%
all_data['weekday']
# Out:
# 0        6
# 1        5
# 2        2
# 3        2
# 4        1
#         ..
# 10881    3
# 10882    5
# 10883    0
# 10884    4
# 10885    2
# Name: weekday, Length: 10886, dtype: int64

# %%
all_data
# Out:
#                   datetime  season  holiday  workingday  weather   temp  \
# 0      2012-06-03 10:00:00       2        0           0        1  25.42
# 1      2012-08-11 10:00:00       3        0           0        1  29.52
# 2      2011-01-05 23:00:00       1        0           1        1   8.20
# 3      2011-04-06 07:00:00       2        0           1        1  10.66
# 4      2012-10-16 05:00:00       4        0           1        1  17.22
# ...                    ...     ...      ...         ...      ...    ...
# 10881  2012-06-14 14:00:00       2        0           1        1  28.70
# 10882  2012-12-01 22:00:00       4        0           0        2  12.30
# 10883  2012-11-19 19:00:00       4        0           1        2  16.40
# 10884  2012-12-14 01:00:00       4        0           1        1   9.02
# 10885  2012-08-15 23:00:00       3        0           1        1  27.88
#
#         atemp  humidity  windspeed  casual  registered  count  year  month  \
# 0      31.060        43    15.0013     127         277    404  2012      6
# 1      34.090        62     6.0032     125         282    407  2012      8
# 2      12.880        47     0.0000       1          18     19  2011      1
# 3      13.635        65     7.0015       3         130    133  2011      4
# 4      21.210        67    16.9979       5          47     52  2012     10
# ...       ...       ...        ...     ...         ...    ...   ...    ...
# 10881  32.575        54    19.0012      84         214    298  2012      6
# 10882  16.665        87     0.0000      17         130    147  2012     12
# 10883  20.455        58    19.0012      25         381    406  2012     11
# 10884  12.880        69     6.0032       0          26     26  2012     12
# 10885  31.820        65     7.0015      18         120    138  2012      8
#
#        hour  weekday
# 0        10        6
# 1        10        5
# 2        23        2
# 3         7        2
# 4         5        1
# ...     ...      ...
# 10881    14        3
# 10882    22        5
# 10883    19        0
# 10884     1        4
# 10885    23        2
#
# [10886 rows x 16 columns]

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
all_data[all_data['weather'] == 4]
# Out:
#                  datetime  season  holiday  workingday  weather  temp   atemp  \
# 5154  2012-01-09 18:00:00       1        0           1        4   8.2  11.365
#
#       humidity  windspeed  casual  registered  count  year  month  hour  \
# 5154        86     6.0032       6         158    164  2012      1    18
#
#       weekday
# 5154        0

# %%
all_data = all_data[all_data['weather'] != 4]

# %%
all_data
# Out:
#                   datetime  season  holiday  workingday  weather   temp  \
# 0      2012-06-03 10:00:00       2        0           0        1  25.42
# 1      2012-08-11 10:00:00       3        0           0        1  29.52
# 2      2011-01-05 23:00:00       1        0           1        1   8.20
# 3      2011-04-06 07:00:00       2        0           1        1  10.66
# 4      2012-10-16 05:00:00       4        0           1        1  17.22
# ...                    ...     ...      ...         ...      ...    ...
# 10881  2012-06-14 14:00:00       2        0           1        1  28.70
# 10882  2012-12-01 22:00:00       4        0           0        2  12.30
# 10883  2012-11-19 19:00:00       4        0           1        2  16.40
# 10884  2012-12-14 01:00:00       4        0           1        1   9.02
# 10885  2012-08-15 23:00:00       3        0           1        1  27.88
#
#         atemp  humidity  windspeed  casual  registered  count  year  month  \
# 0      31.060        43    15.0013     127         277    404  2012      6
# 1      34.090        62     6.0032     125         282    407  2012      8
# 2      12.880        47     0.0000       1          18     19  2011      1
# 3      13.635        65     7.0015       3         130    133  2011      4
# 4      21.210        67    16.9979       5          47     52  2012     10
# ...       ...       ...        ...     ...         ...    ...   ...    ...
# 10881  32.575        54    19.0012      84         214    298  2012      6
# 10882  16.665        87     0.0000      17         130    147  2012     12
# 10883  20.455        58    19.0012      25         381    406  2012     11
# 10884  12.880        69     6.0032       0          26     26  2012     12
# 10885  31.820        65     7.0015      18         120    138  2012      8
#
#        hour  weekday
# 0        10        6
# 1        10        5
# 2        23        2
# 3         7        2
# 4         5        1
# ...     ...      ...
# 10881    14        3
# 10882    22        5
# 10883    19        0
# 10884     1        4
# 10885    23        2
#
# [10885 rows x 16 columns]

# %%
all_data.columns
# Out:
# Index(['datetime', 'season', 'holiday', 'workingday', 'weather', 'temp',
#        'atemp', 'humidity', 'windspeed', 'casual', 'registered', 'count',
#        'year', 'month', 'hour', 'weekday'],
#       dtype='object')

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
drop_features = ['casual', 'registered', 'datetime', 'windspeed']

# %%
all_data = all_data.drop(drop_features, axis = 1)

# %%
all_data
# Out:
#        season  holiday  workingday  weather   temp   atemp  humidity  count  \
# 0           2        0           0        1  25.42  31.060        43    404
# 1           3        0           0        1  29.52  34.090        62    407
# 2           1        0           1        1   8.20  12.880        47     19
# 3           2        0           1        1  10.66  13.635        65    133
# 4           4        0           1        1  17.22  21.210        67     52
# ...       ...      ...         ...      ...    ...     ...       ...    ...
# 10881       2        0           1        1  28.70  32.575        54    298
# 10882       4        0           0        2  12.30  16.665        87    147
# 10883       4        0           1        2  16.40  20.455        58    406
# 10884       4        0           1        1   9.02  12.880        69     26
# 10885       3        0           1        1  27.88  31.820        65    138
#
#        year  month  hour  weekday
# 0      2012      6    10        6
# 1      2012      8    10        5
# 2      2011      1    23        2
# 3      2011      4     7        2
# 4      2012     10     5        1
# ...     ...    ...   ...      ...
# 10881  2012      6    14        3
# 10882  2012     12    22        5
# 10883  2012     11    19        0
# 10884  2012     12     1        4
# 10885  2012      8    23        2
#
# [10885 rows x 12 columns]

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
del all_data['month']

# %%
all_data
# Out:
#        season  holiday  workingday  weather   temp   atemp  humidity  count  \
# 0           2        0           0        1  25.42  31.060        43    404
# 1           3        0           0        1  29.52  34.090        62    407
# 2           1        0           1        1   8.20  12.880        47     19
# 3           2        0           1        1  10.66  13.635        65    133
# 4           4        0           1        1  17.22  21.210        67     52
# ...       ...      ...         ...      ...    ...     ...       ...    ...
# 10881       2        0           1        1  28.70  32.575        54    298
# 10882       4        0           0        2  12.30  16.665        87    147
# 10883       4        0           1        2  16.40  20.455        58    406
# 10884       4        0           1        1   9.02  12.880        69     26
# 10885       3        0           1        1  27.88  31.820        65    138
#
#        year  hour  weekday
# 0      2012    10        6
# 1      2012    10        5
# 2      2011    23        2
# 3      2011     7        2
# 4      2012     5        1
# ...     ...   ...      ...
# 10881  2012    14        3
# 10882  2012    22        5
# 10883  2012    19        0
# 10884  2012     1        4
# 10885  2012    23        2
#
# [10885 rows x 11 columns]

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
X_train = all_data[0:8707]

# %%
all_data[0:8707]
# Out:
#       season  holiday  workingday  weather   temp   atemp  humidity  count  \
# 0          2        0           0        1  25.42  31.060        43    404
# 1          3        0           0        1  29.52  34.090        62    407
# 2          1        0           1        1   8.20  12.880        47     19
# 3          2        0           1        1  10.66  13.635        65    133
# 4          4        0           1        1  17.22  21.210        67     52
# ...      ...      ...         ...      ...    ...     ...       ...    ...
# 8703       4        0           0        2  10.66  15.150        81     50
# 8704       4        0           1        1  18.04  21.970        88    153
# 8705       3        0           0        1  29.52  35.605        84    356
# 8706       2        0           0        1  25.42  31.060        33    678
# 8707       3        0           0        2  26.24  30.305        69     74
#
#       year  hour  weekday
# 0     2012    10        6
# 1     2012    10        5
# 2     2011    23        2
# 3     2011     7        2
# 4     2012     5        1
# ...    ...   ...      ...
# 8703  2012     2        5
# 8704  2012     6        3
# 8705  2012    20        5
# 8706  2012    13        5
# 8707  2011     1        5
#
# [8707 rows x 11 columns]

# %%
X_test = all_data[8707 : ]

# %%
all_data[8707 : ]
# Out:
#        season  holiday  workingday  weather   temp   atemp  humidity  count  \
# 8708        4        0           0        1  14.76  17.425        66    210
# 8709        1        0           1        2   8.20   8.335        44     37
# 8710        3        0           0        2  25.42  30.305        69    119
# 8711        3        0           1        1  22.96  26.515        88     20
# 8712        2        0           1        2  21.32  25.000        83      4
# ...       ...      ...         ...      ...    ...     ...       ...    ...
# 10881       2        0           1        1  28.70  32.575        54    298
# 10882       4        0           0        2  12.30  16.665        87    147
# 10883       4        0           1        2  16.40  20.455        58    406
# 10884       4        0           1        1   9.02  12.880        69     26
# 10885       3        0           1        1  27.88  31.820        65    138
#
#        year  hour  weekday
# 8708   2012    19        6
# 8709   2011    11        3
# 8710   2012     2        6
# 8711   2011     5        1
# 8712   2012     3        0
# ...     ...   ...      ...
# 10881  2012    14        3
# 10882  2012    22        5
# 10883  2012    19        0
# 10884  2012     1        4
# 10885  2012    23        2
#
# [2178 rows x 11 columns]

# %%
y_train = X_train[['count']]
y_test = X_test[['count']]

# %%
del X_train['count']
del X_test['count']

# %%
X_train
# Out:
#       season  holiday  workingday  weather   temp   atemp  humidity  year  \
# 0          2        0           0        1  25.42  31.060        43  2012
# 1          3        0           0        1  29.52  34.090        62  2012
# 2          1        0           1        1   8.20  12.880        47  2011
# 3          2        0           1        1  10.66  13.635        65  2011
# 4          4        0           1        1  17.22  21.210        67  2012
# ...      ...      ...         ...      ...    ...     ...       ...   ...
# 8703       4        0           0        2  10.66  15.150        81  2012
# 8704       4        0           1        1  18.04  21.970        88  2012
# 8705       3        0           0        1  29.52  35.605        84  2012
# 8706       2        0           0        1  25.42  31.060        33  2012
# 8707       3        0           0        2  26.24  30.305        69  2011
#
#       hour  weekday
# 0       10        6
# 1       10        5
# 2       23        2
# 3        7        2
# 4        5        1
# ...    ...      ...
# 8703     2        5
# 8704     6        3
# 8705    20        5
# 8706    13        5
# 8707     1        5
#
# [8707 rows x 10 columns]

# %%
y_train
# Out:
#       count
# 0       404
# 1       407
# 2        19
# 3       133
# 4        52
# ...     ...
# 8703     50
# 8704    153
# 8705    356
# 8706    678
# 8707     74
#
# [8707 rows x 1 columns]

# %%
X_test
# Out:
#        season  holiday  workingday  weather   temp   atemp  humidity  year  \
# 8708        4        0           0        1  14.76  17.425        66  2012
# 8709        1        0           1        2   8.20   8.335        44  2011
# 8710        3        0           0        2  25.42  30.305        69  2012
# 8711        3        0           1        1  22.96  26.515        88  2011
# 8712        2        0           1        2  21.32  25.000        83  2012
# ...       ...      ...         ...      ...    ...     ...       ...   ...
# 10881       2        0           1        1  28.70  32.575        54  2012
# 10882       4        0           0        2  12.30  16.665        87  2012
# 10883       4        0           1        2  16.40  20.455        58  2012
# 10884       4        0           1        1   9.02  12.880        69  2012
# 10885       3        0           1        1  27.88  31.820        65  2012
#
#        hour  weekday
# 8708     19        6
# 8709     11        3
# 8710      2        6
# 8711      5        1
# 8712      3        0
# ...     ...      ...
# 10881    14        3
# 10882    22        5
# 10883    19        0
# 10884     1        4
# 10885    23        2
#
# [2178 rows x 10 columns]

# %%
y_test
# Out:
#        count
# 8708     210
# 8709      37
# 8710     119
# 8711      20
# 8712       4
# ...      ...
# 10881    298
# 10882    147
# 10883    406
# 10884     26
# 10885    138
#
# [2178 rows x 1 columns]

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def RMSLE(y_true, y_pred, convertExp):
    # 로그값을 넣으면 지수변환, 실제값을 넣으면 하지 않음
    if convertExp: # 입력값이 로그로 들어오면 지수변환
        y_true = np.exp(y_true)
        y_pred = np.exp(y_pred)
    # 로그변환 후 결측값을 0으로 변환
    log_true = np.nan_to_num(np.log(y_true + 1)) 
    log_pred = np.nan_to_num(np.log(y_pred + 1))
    # nan_to_num = 결측값이 존재할때 에러방지 결측값이 0으로 설정됨
    
    # RMSLE 계산
    output = np.sqrt(np.mean((log_true - log_pred) ** 2))
    #         제곱근   평균           차이의 제곱
    return output

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from sklearn.linear_model import LinearRegression
Lin_model = LinearRegression()

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
log_y_train = np.log(y_train)
log_y_test = np.log(y_test)
Lin_model.fit(X_train, log_y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
Lin_model.coef_
# Out:
# array([[ 0.18075577,  0.02317785, -0.00587388, -0.00668758,  0.0131375 ,
#          0.03163726, -0.0151898 ,  0.43768858,  0.10435207,  0.0265815 ]])

# %%
Lin_model.intercept_
# Out:
# array([-877.66154803])

# %%
log_y_train
# Out:
#          count
# 0     6.001415
# 1     6.008813
# 2     2.944439
# 3     4.890349
# 4     3.951244
# ...        ...
# 8703  3.912023
# 8704  5.030438
# 8705  5.874931
# 8706  6.519147
# 8707  4.304065
#
# [8707 rows x 1 columns]

# %%
Lin_model.predict(X_train)
# Out:
# array([[5.18915978],
#        [5.20445256],
#        [4.95294017],
#        ...,
#        [5.96172823],
#        [5.62753246],
#        [3.55174114]])

# %%
Lin_model.predict(X_test)
# Out:
# array([[5.56905488],
#        [3.62238726],
#        [4.10959054],
#        ...,
#        [5.63592916],
#        [3.36691067],
#        [6.33647966]])

# %%
RMSLE(log_y_train, Lin_model.predict(X_train), True)
# Out:
# 1.0214740413779702

# %%
RMSLE(log_y_test, Lin_model.predict(X_test), True)
# Out:
# 1.0178845331327868

# %%
plt.figure(figsize = (10, 5))
x = np.linspace(0, 7)
y = x
lines = plt.plot(Lin_model.predict(X_train), log_y_train, 'o', x, y, 'k')
plt.setp(lines[0], markersize = 7)
plt.setp(lines[1], linewidth = 3)
plt.xlabel('Predicted')
plt.ylabel('Observed')
plt.show()

# %%
plt.figure(figsize = (10, 5))
x = np.linspace(0, 7)
y = x
lines = plt.plot(Lin_model.predict(X_test), log_y_test, 'o', x, y, 'k')
plt.setp(lines[0], markersize = 7)
plt.setp(lines[1], linewidth = 3)
plt.xlabel('Predicted')
plt.ylabel('Observed')
plt.show()
