# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# pd.read_csv로 csv파일 불러오기
train = pd.read_csv('train.csv')
train.head()
# Out:
#               datetime  season  holiday  workingday  weather  temp   atemp  \
# 0  2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 1  2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2  2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 3  2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 4  2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#    humidity  windspeed  casual  registered  count
# 0        81        0.0       3          13     16
# 1        80        0.0       8          32     40
# 2        80        0.0       5          27     32
# 3        75        0.0       3          10     13
# 4        75        0.0       0           1      1

# %%
train.shape # 데이터의 크기 몇행 몇열
# Out:
# (10886, 12)

# %%
# pd.read_csv로 csv파일 불러오기
test = pd.read_csv('test.csv')
test.head()
# Out:
#               datetime  season  holiday  workingday  weather   temp   atemp  \
# 0  2011-01-20 00:00:00       1        0           1        1  10.66  11.365
# 1  2011-01-20 01:00:00       1        0           1        1  10.66  13.635
# 2  2011-01-20 02:00:00       1        0           1        1  10.66  13.635
# 3  2011-01-20 03:00:00       1        0           1        1  10.66  12.880
# 4  2011-01-20 04:00:00       1        0           1        1  10.66  12.880
#
#    humidity  windspeed
# 0        56    26.0027
# 1        56     0.0000
# 2        56     0.0000
# 3        56    11.0014
# 4        56    11.0014

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10886 entries, 0 to 10885
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   datetime    10886 non-null  object
#  1   season      10886 non-null  int64
#  2   holiday     10886 non-null  int64
#  3   workingday  10886 non-null  int64
#  4   weather     10886 non-null  int64
#  5   temp        10886 non-null  float64
#  6   atemp       10886 non-null  float64
#  7   humidity    10886 non-null  int64
#  8   windspeed   10886 non-null  float64
#  9   casual      10886 non-null  int64
#  10  registered  10886 non-null  int64
#  11  count       10886 non-null  int64
# dtypes: float64(3), int64(8), object(1)
# memory usage: 1020.7+ KB

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
train['datetime'][0]
# Out:
# '2011-01-01 00:00:00'

# %%
train['datetime'][0].split()
# Out:
# ['2011-01-01', '00:00:00']

# %%
train['datetime'][0].split()[0]
# Out:
# '2011-01-01'

# %%
train['datetime'][0].split()[0].split('-')
# Out:
# ['2011', '01', '01']

# %%
train['datetime'][0].split()[0].split('-')[0]
# Out:
# '2011'

# %%
train['datetime'][0].split()[1].split(':')
# Out:
# ['00', '00', '00']

# %%
train['datetime'][0].split()[1].split(':')[0]
# Out:
# '00'

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
train['datetime'].apply(lambda x: x.split()[0].split('-')[0])
# Out:
# 0        2011
# 1        2011
# 2        2011
# 3        2011
# 4        2011
#          ...
# 10881    2012
# 10882    2012
# 10883    2012
# 10884    2012
# 10885    2012
# Name: datetime, Length: 10886, dtype: object

# %%
from datetime import datetime
import calendar

# %%
datetime.strptime(train['datetime'][0].split()[0], "%Y-%m-%d").year
# Out:
# 2011

# %%
datetime.strptime(train['datetime'][0].split()[0], "%Y-%m-%d").month
# Out:
# 1

# %%
datetime.strptime(train['datetime'][0].split()[0], "%Y-%m-%d").day
# Out:
# 1

# %%
datetime.strptime(train['datetime'][0].split()[0], "%Y-%m-%d").weekday()
# Out:
# 5

# %%
calendar.day_name[datetime.strptime(train['datetime'][0].split()[0], "%Y-%m-%d").weekday()]
# Out:
# 'Saturday'

# %%
train['year'] = train['datetime'].apply(lambda x: datetime.strptime(x.split()[0], "%Y-%m-%d").year)

# %%
train['year']
# Out:
# 0        2011
# 1        2011
# 2        2011
# 3        2011
# 4        2011
#          ...
# 10881    2012
# 10882    2012
# 10883    2012
# 10884    2012
# 10885    2012
# Name: year, Length: 10886, dtype: int64

# %%
train['month'] = train['datetime'].apply(lambda x: datetime.strptime(x.split()[0], "%Y-%m-%d").month)

# %%
train['month']
# Out:
# 0         1
# 1         1
# 2         1
# 3         1
# 4         1
#          ..
# 10881    12
# 10882    12
# 10883    12
# 10884    12
# 10885    12
# Name: month, Length: 10886, dtype: int64

# %%
train['day'] = train['datetime'].apply(lambda x: datetime.strptime(x.split()[0], "%Y-%m-%d").day)

# %%
train['day']
# Out:
# 0         1
# 1         1
# 2         1
# 3         1
# 4         1
#          ..
# 10881    19
# 10882    19
# 10883    19
# 10884    19
# 10885    19
# Name: day, Length: 10886, dtype: int64

# %%
train['hour'] = train['datetime'].apply(lambda x: x.split()[1].split(':')[0])

# %%
train['hour']
# Out:
# 0        00
# 1        01
# 2        02
# 3        03
# 4        04
#          ..
# 10881    19
# 10882    20
# 10883    21
# 10884    22
# 10885    23
# Name: hour, Length: 10886, dtype: object

# %%
train['minute'] = train['datetime'].apply(lambda x: x.split()[1].split(':')[1])

# %%
train['minute']
# Out:
# 0        00
# 1        00
# 2        00
# 3        00
# 4        00
#          ..
# 10881    00
# 10882    00
# 10883    00
# 10884    00
# 10885    00
# Name: minute, Length: 10886, dtype: object

# %%
train['second'] = train['datetime'].apply(lambda x: x.split()[1].split(':')[2])

# %%
train['second']
# Out:
# 0        00
# 1        00
# 2        00
# 3        00
# 4        00
#          ..
# 10881    00
# 10882    00
# 10883    00
# 10884    00
# 10885    00
# Name: second, Length: 10886, dtype: object

# %%
train['weekday'] = train['datetime'].apply(lambda x: calendar.day_name[datetime.strptime(x.split()[0], "%Y-%m-%d").weekday()])

# %%
train['weekday']
# Out:
# 0         Saturday
# 1         Saturday
# 2         Saturday
# 3         Saturday
# 4         Saturday
#            ...
# 10881    Wednesday
# 10882    Wednesday
# 10883    Wednesday
# 10884    Wednesday
# 10885    Wednesday
# Name: weekday, Length: 10886, dtype: object

# %%
train
# Out:
#                   datetime  season  holiday  workingday  weather   temp  \
# 0      2011-01-01 00:00:00       1        0           0        1   9.84
# 1      2011-01-01 01:00:00       1        0           0        1   9.02
# 2      2011-01-01 02:00:00       1        0           0        1   9.02
# 3      2011-01-01 03:00:00       1        0           0        1   9.84
# 4      2011-01-01 04:00:00       1        0           0        1   9.84
# ...                    ...     ...      ...         ...      ...    ...
# 10881  2012-12-19 19:00:00       4        0           1        1  15.58
# 10882  2012-12-19 20:00:00       4        0           1        1  14.76
# 10883  2012-12-19 21:00:00       4        0           1        1  13.94
# 10884  2012-12-19 22:00:00       4        0           1        1  13.94
# 10885  2012-12-19 23:00:00       4        0           1        1  13.12
#
#         atemp  humidity  windspeed  casual  registered  count  year  month  \
# ...

# %%
train['season'] = train['season'].map({ 1 : 'Spring',
                                       2 : 'Summer',
                                       3 : 'Fall',
                                       4 : "Winter"})

# %%
train['weather'] = train['weather'].map({ 1 : 'Clear',
                                       2 : 'Mist, tew clouds',
                                       3 : 'Light snow, rain, thunderstrom',
                                       4 : "Heavy snow, rain, thunderstrom"})

# %%
train
# Out:
#                   datetime  season  holiday  workingday weather   temp  \
# 0      2011-01-01 00:00:00  Spring        0           0   Clear   9.84
# 1      2011-01-01 01:00:00  Spring        0           0   Clear   9.02
# 2      2011-01-01 02:00:00  Spring        0           0   Clear   9.02
# 3      2011-01-01 03:00:00  Spring        0           0   Clear   9.84
# 4      2011-01-01 04:00:00  Spring        0           0   Clear   9.84
# ...                    ...     ...      ...         ...     ...    ...
# 10881  2012-12-19 19:00:00  Winter        0           1   Clear  15.58
# 10882  2012-12-19 20:00:00  Winter        0           1   Clear  14.76
# 10883  2012-12-19 21:00:00  Winter        0           1   Clear  13.94
# 10884  2012-12-19 22:00:00  Winter        0           1   Clear  13.94
# 10885  2012-12-19 23:00:00  Winter        0           1   Clear  13.12
#
#         atemp  humidity  windspeed  casual  registered  count  year  month  \
# ...

# %%
import seaborn as sns
import matplotlib as mpl

# %%
sns.displot(train['count'])

# %%
sns.displot(np.log(train['count']))

# %%
sns.barplot(x = 'year', y = 'count', data = train)
# Out:
# <AxesSubplot:xlabel='year', ylabel='count'>

# %%
sns.barplot(x = 'month', y = 'count', data = train)
# Out:
# <AxesSubplot:xlabel='month', ylabel='count'>

# %%
sns.barplot(x = 'day', y = 'count', data = train)
# Out:
# <AxesSubplot:xlabel='day', ylabel='count'>

# %%
sns.barplot(x = 'hour', y = 'count', data = train)
# Out:
# <AxesSubplot:xlabel='hour', ylabel='count'>

# %%
sns.barplot(x = 'minute', y = 'count', data = train)
# Out:
# <AxesSubplot:xlabel='minute', ylabel='count'>

# %%
sns.barplot(x = 'second', y = 'count', data = train)
# Out:
# <AxesSubplot:xlabel='second', ylabel='count'>

# %%
# 스텝 1 : m행 n열 Figure 준비
figure, axes = plt.subplots(nrows = 3, ncols = 2)
mpl.rc('font', size = 14)
mpl.rc('axes', titlesize = 15)
plt.tight_layout()
figure.set_size_inches(10, 9)

# 스텝 2 : 각 축에 서브플롯 할당
sns.barplot(x = 'year', y = 'count', data = train, ax = axes[0, 0])
sns.barplot(x = 'month', y = 'count', data = train, ax = axes[0, 1])
sns.barplot(x = 'day', y = 'count', data = train, ax = axes[1, 0])
sns.barplot(x = 'hour', y = 'count', data = train, ax = axes[1, 1])
sns.barplot(x = 'minute', y = 'count', data = train, ax = axes[2, 0])
sns.barplot(x = 'second', y = 'count', data = train, ax = axes[2, 1])

# 스텝 3 : 세부 설정
# 3 - 1 : 서브플롯에 제목달기
axes[0, 0].set(title = "Rental amounts by year")
axes[0, 1].set(title = "Rental amounts by month")
axes[1, 0].set(title = "Rental amounts by day")
axes[1, 1].set(title = "Rental amounts by hour")
axes[2, 0].set(title = "Rental amounts by minute")
axes[2, 1].set(title = "Rental amounts by second")

# 3 - 2 : 1행에 위치한 서브플롯들의 x출 라벨 90도 회전
axes[1, 0].tick_params(axis = 'x', labelrotation = 90)
axes[1, 1].tick_params(axis = 'x', labelrotation = 90)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 계절과 대여수 박스플롯

# %%
sns.boxplot(x = 'season', y = 'count', data = train)
# Out:
# <AxesSubplot:xlabel='season', ylabel='count'>

# %% [markdown]
# # 날씨와 대여수 박스플롯

# %%
ax = sns.boxplot(x = 'weather', y = 'count', data = train)
ax.tick_params('x', labelrotation = 10)

# %%
sns.boxplot(x = 'holiday', y = 'count', data = train)
# Out:
# <AxesSubplot:xlabel='holiday', ylabel='count'>

# %%
sns.boxplot(x = 'workingday', y = 'count', data = train)
# Out:
# <AxesSubplot:xlabel='workingday', ylabel='count'>

# %%
# 스텝 1 : m행 n열 Figure 준비
figure, axes = plt.subplots(nrows=2, ncols=2)
plt.tight_layout()
figure.set_size_inches(10, 10)

# 스텝 2 : 서브플롯 할당
# 계절, 날씨, 공휴일, 근무일별 대여 수량 박스플록
sns.boxplot(x = 'season', y = 'count', data = train, ax = axes[0,0])
sns.boxplot(x = 'weather', y = 'count', data = train, ax = axes[0,1])
sns.boxplot(x = 'holiday', y = 'count', data = train, ax = axes[1,0])
sns.boxplot(x = 'workingday', y = 'count', data = train, ax = axes[1,1])

# 스텝 3 : 세부 설정
# 3-1 : 서브플롯에 제목 달기
axes[0, 0].set(title = 'Box Plot On Count Across Season')
axes[0, 1].set(title = 'Box Plot On Count Across Weather')
axes[1, 0].set(title = 'Box Plot On Count Across Holiday')
axes[1, 1].set(title = 'Box Plot On Count Across Working Day')

# 3-2 : x축 라벨 겹침 해결
axes[0,1].tick_params('x', labelrotation = 10)

# %%
plt.figure(figsize = (12, 5))
sns.pointplot(x = 'hour', y = 'count', data = train, hue = 'workingday')
# Out:
# <AxesSubplot:xlabel='hour', ylabel='count'>

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
plt.figure(figsize = (12, 5))
sns.pointplot(x = 'hour', y = 'count', data = train, hue = 'weekday')
# Out:
# <AxesSubplot:xlabel='hour', ylabel='count'>

# %%
plt.figure(figsize = (12, 5))
sns.pointplot(x = 'hour', y = 'count', data = train, hue = 'season')
# Out:
# <AxesSubplot:xlabel='hour', ylabel='count'>

# %%
plt.figure(figsize = (12, 5))
sns.pointplot(x = 'hour', y = 'count', data = train, hue = 'weather')
# Out:
# <AxesSubplot:xlabel='hour', ylabel='count'>

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
sns.regplot(x = 'temp', y = 'count', data = train, line_kws = {'color' : 'red'})
# Out:
# <AxesSubplot:xlabel='temp', ylabel='count'>

# %%
sns.jointplot(x = 'temp', y = 'count', data = train, kind = 'reg', line_kws = {'color' : 'red'})
# jointplot는 reg선을 설정해줘야 나타난다.

# %%
sns.jointplot(x = 'atemp', y = 'count', data = train, kind = 'reg', line_kws = {'color' : 'red'})
# jointplot는 reg선을 설정해줘야 나타난다.

# %%
sns.jointplot(x = 'humidity', y = 'count', data = train, kind = 'reg', line_kws = {'color' : 'red'})

# %%
sns.jointplot(x = 'windspeed', y = 'count', data = train, kind = 'reg', line_kws = {'color' : 'red'})

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
train.columns
# Out:
# Index(['datetime', 'season', 'holiday', 'workingday', 'weather', 'temp',
#        'atemp', 'humidity', 'windspeed', 'casual', 'registered', 'count',
#        'year', 'month', 'day', 'hour', 'minute', 'second', 'weekday'],
#       dtype='object')

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
train[['count', 'temp', 'atemp', 'humidity', 'windspeed']].corr()
# Out:
#               count      temp     atemp  humidity  windspeed
# count      1.000000  0.394454  0.389784 -0.317371   0.101369
# temp       0.394454  1.000000  0.984948 -0.064949  -0.017852
# atemp      0.389784  0.984948  1.000000 -0.043536  -0.057473
# humidity  -0.317371 -0.064949 -0.043536  1.000000  -0.318607
# windspeed  0.101369 -0.017852 -0.057473 -0.318607   1.000000

# %%
# 피처 간 상관관계 매트릭스
corrMat = train[['count', 'temp', 'atemp', 'humidity', 'windspeed']].corr()
fig, ax = plt.subplots()
fig.set_size_inches(10, 10)
sns.heatmap(corrMat, cmap = 'bwr', annot = True) # 상관관계 히트맵 그리기
ax.set(title = 'Heatmap of Numerical Data')
# Out:
# [Text(0.5, 1.0, 'Heatmap of Numerical Data')]

# %% [markdown]
# ![image.png](attachment:image.png)
